# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("1k_fit_parameters.csv")

# %%
plt.scatter(df["momentum"],df["ca_thtrA_mean"],c=df['eta'])

plt.xlabel("p [GeV/c]")
plt.ylabel("$\\theta_c [mrad]$")
plt.title("Aerogel")
plt.show()

plt.savefig("aerogel.png")
plt.scatter(df["momentum"],df["cg_thtrG_mean"],c=df['eta'])
plt.xlabel("p [GeV/c]")
plt.ylabel("$\\theta_c [mrad]$")
plt.title("Gas")
plt.show()
plt.savefig("gas.png")
